# %%
# Strategy Validation - Reproduce Your Successful Volatility Skew Strategy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os

# Add src to path to import our modules
sys.path.append('src')

from data.data_loader import BloombergDataLoader
from signals.signal_generator import VolatilitySkewSignals
from backtesting.performance_tracker import PerformanceTracker

# Set up plotting
plt.style.use('seaborn-v0_8')
plt.rcParams['figure.figsize'] = (12, 8)
sns.set_palette("husl")

print("=== VOLATILITY SKEW STRATEGY VALIDATION ===\n")
print("🎯 Objective: Reproduce Excel strategy with Sharpe 0.78 and 38.5% win rate")
